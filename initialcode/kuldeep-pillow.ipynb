# %%
# Load the required modules
from PIL import Image
import numpy as np
import os
import glob

# %%
image=Image.open('images/vehicle/vehicle5.jpg')

# %%
image.load()

# %%
data=np.asarray(image, dtype="int32")

# %%
print(image.mode)
# Out:
# RGB

# %%
image_resize=image.resize((800,1000))

# %%
print(image_resize.size)
# Out:
# (800, 1000)

# %%
# I have images created in 5 folders
# !ls -l images
# Out:
# total 0
# drwxr-xr-x  23 kuldeepsingh  staff  736 Nov 13 17:30 building
# drwxr-xr-x  23 kuldeepsingh  staff  736 Nov 13 17:31 food
# drwxr-xr-x  22 kuldeepsingh  staff  704 Nov 13 17:31 nature
# drwxr-xr-x  22 kuldeepsingh  staff  704 Nov 13 17:31 person
# drwxr-xr-x  22 kuldeepsingh  staff  704 Nov 13 17:31 vehicle

# %%
folders=glob.glob('images/*')
imagenames_list=([])

# %%
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

# %%
read_images=([])

# %%
for image in imagenames_list:
    read_images.append(Image.open(image))
    #read_images.append(image.resize((800,1000)))

# %%
# for image in imagenames_list:
#     read_images.append(image.((800,1000)))

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
len(read_images)
# Out:
# 100

# %%
plt.imshow(read_images[80])
